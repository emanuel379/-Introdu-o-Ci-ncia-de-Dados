# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuel379/-Introdu-o-Ci-ncia-de-Dados/blob/main/ICD_Atividade_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# 1

lmbd = 1 # taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 1', fontsize = 16)
plt.show(True)

lmbd = 2 # taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 2', fontsize = 16)
plt.show(True)

lmbd = 3 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 3', fontsize = 16)
plt.show(True)

lmbd = 4 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 4', fontsize = 16)
plt.show(True)

lmbd = 5 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 5', fontsize = 16)
plt.show(True)

lmbd = 6 # taxa
n = 100
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 6', fontsize = 16)
plt.show(True)

lmbd = 7 # taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 7', fontsize = 16)
plt.show(True)

lmbd = 8 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 8', fontsize = 16)
plt.show(True)

lmbd = 9 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 9', fontsize = 16)
plt.show(True)

lmbd = 10 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 10', fontsize = 16)
plt.show(True)

# %%
# 2

from zipfile import ZipFile
file_name = 'data (4).zip'
with ZipFile(file_name, 'r') as zip:

    zip.printdir()


    print('Extracting all the files now...')
    zip.extractall()
    print('Done!')
# Out:
# File Name                                             Modified             Size
# data/                                          2020-11-16 23:34:20            0
# __MACOSX/._data                                2020-11-16 23:34:20          177
# data/houses_to_rent.csv                        2020-03-15 01:12:22       471498
# __MACOSX/data/._houses_to_rent.csv             2020-03-15 01:12:22          426
# data/Advertising.csv                           2019-09-26 05:11:42         4756
# __MACOSX/data/._Advertising.csv                2019-09-26 05:11:42          426
# data/breastcancer_test.csv                     2018-03-24 16:58:30         4762
# __MACOSX/data/._breastcancer_test.csv          2018-03-24 16:58:30          389
# data/.DS_Store                                 2020-11-16 23:34:52         6148
# __MACOSX/data/._.DS_Store                      2020-11-16 23:34:52          120
# data/breastcancer_training.csv                 2018-03-24 16:58:30         7892
# __MACOSX/data/._breastcancer_training.csv      2018-03-24 16:58:30          389
# data/Vehicle.csv                               2018-03-24 16:58:30        57003
# __MACOSX/data/._Vehicle.csv                    2018-03-24 16:58:30          388
# data/concrete_data.csv                         2019-09-21 01:26:24        59010
# __MACOSX/data/._concrete_data.csv              2019-09-21 01:26:24          370
# data/iris-with-errors.csv                      2019-02-26 20:30:40          639
# __MACOSX/data/._iris-with-errors.csv           2019-02-26 20:30:40          499
# data/winequality-red.csv                       2020-03-21 11:36:06       100951
# __MACOSX/data/._winequality-red.csv            2020-03-21 11:36:06         1277
# data/iris.csv                                  2019-02-26 20:13:08         3716
# __MACOSX/data/._iris.csv                       2019-02-26 20:13:08          511
# data/BreastCancer.csv                          2018-03-24 16:58:30        33993
# __MACOSX/data/._BreastCancer.csv               2018-03-24 16:58:30          389
# data/BostonHousing.csv                         2018-03-24 16:58:30        35735
# __MACOSX/data/._BostonHousing.csv              2018-03-24 16:58:30          389
# data/titanic/                                  2020-02-08 23:16:18            0
# __MACOSX/data/._titanic                        2020-02-08 23:16:18          270
# data/titanic.zip                               2020-11-16 23:34:20        36232
# __MACOSX/data/._titanic.zip                    2020-11-16 23:34:20          178
# data/vertebralcolumn-2C.csv                    2020-01-09 03:53:18        20998
# __MACOSX/data/._vertebralcolumn-2C.csv         2020-01-09 03:53:18          270
# data/vertebralcolumn-3C.csv                    2020-01-09 03:53:18        22228
# __MACOSX/data/._vertebralcolumn-3C.csv         2020-01-09 03:53:18          270
# data/opsd_germany_daily.csv                    2019-12-30 23:40:16       217983
# __MACOSX/data/._opsd_germany_daily.csv         2019-12-30 23:40:16          590
# data/titanic/test.csv                          2019-12-11 02:17:12        28629
# __MACOSX/data/titanic/._test.csv               2019-12-11 02:17:12          270
# data/titanic/train.csv                         2019-12-11 02:17:12        61194
# __MACOSX/data/titanic/._train.csv              2019-12-11 02:17:12          270
# data/titanic/gender_submission.csv             2019-12-11 02:17:12         3258
# __MACOSX/data/titanic/._gender_submission.csv  2019-12-11 02:17:12          270
# Extracting all the files now...
# Done!

# %%
df2 = pd.read_csv('data/iris.csv')
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df2['sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
df2['sepal_width'].mean()
# Out:
# 3.0540000000000003

# %%
df2['petal_length'].mean()
# Out:
# 3.758666666666666

# %%
df2['petal_width'].mean()
# Out:
# 1.1986666666666668

# %%
df2['sepal_length'].var()
# Out:
# 0.6856935123042507

# %%
df2['sepal_width'].var()
# Out:
# 0.1880040268456376

# %%
df2['petal_length'].var()
# Out:
# 3.113179418344519

# %%
df2['petal_width'].var()
# Out:
# 0.582414317673378

# %%
from scipy.stats import iqr # Iqr = Amplitude interquartil(q3 - q1)

iqr(df2['sepal_length'])
# Out:
# 1.3000000000000007

# %%
iqr(df2['sepal_width'])
# Out:
# 0.5

# %%
iqr(df2['petal_length'])
# Out:
# 3.4999999999999996

# %%
iqr(df2['petal_width'])
# Out:
# 1.5

# %%
# 3

plt.figure(figsize=(10, 8))
sns.boxplot(data = df2['sepal_length'], showmeans=True, meanprops={"marker": "*", "markeredgecolor": "black", "markersize": "10"}).set(title="Comprimento das sépalas observado")
plt.xlabel("Boxplot", fontsize = 12)
plt.ylabel("Comprimento das sépalas", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data = df2['sepal_width'], showmeans=True, meanprops={"marker": "*", "markeredgecolor": "black", "markersize": "10"}).set(title = "Largura das sépalas observada")
plt.xlabel("Boxplot", fontsize = 12)
plt.ylabel("Largura das sépalas", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data = df2['petal_length'], showmeans=True, meanprops={"marker": "*", "markeredgecolor": "black", "markersize": "10"}).set(title="Comprimento das pétalas observado")
plt.xlabel("Boxplot", fontsize = 12)
plt.ylabel("Comprimento das pétalas", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data = df2['petal_width'], showmeans=True, meanprops={"marker": "*", "markeredgecolor": "black", "markersize": "10"}).set(title="Largura das pétalas observada")
plt.xlabel("Boxplot", fontsize = 12)
plt.ylabel("Largura das pétalas", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data = df2[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']], showmeans=True, meanprops={"marker": "*", "markeredgecolor": "black", "markersize": "10"}).set(title="Comparando nossos dados")
plt.xlabel("Boxplots com os dados", fontsize = 12)
plt.ylabel("Tamanhos observados", fontsize = 12)
plt.show()

# %%
# 4

from scipy.stats import pearsonr, spearmanr

N = 10
x = np.linspace(1, 50000, N)
z = np.log(x)

plt.plot(x, z)
plt.xlabel("x",fontsize = 20)
plt.ylabel("Log(X)", fontsize = 20)
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

N = 100
x = np.linspace(1, 50000, N)
z = np.log(x)

plt.plot(x, z)
plt.xlabel("x",fontsize = 20)
plt.ylabel("Log(X)", fontsize = 20)
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

N = 1000
x = np.linspace(1, 50000, N)
z = np.log(x)

plt.plot(x, z)
plt.xlabel("x",fontsize = 20)
plt.ylabel("Log(X)", fontsize = 20)
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.show()

# %%
# 5

# Com Pearson

N = 100
X = np.linspace(-1, 1, N)
erro = np.random.uniform(-1,1,N) # ruído a ser incluído na relação linear.
for sigma in np.arange(0,3,0.2):
    Y = 0.5*X + erro*sigma
    plt.plot(X,Y, 'ro')
    corr, p_value = pearsonr(X, Y) # calcula a correlação
    corr = int(corr*100)/100
    string = 'corr = '+ str(corr)
    plt.text(0.6,1.7, string, fontsize=15)
    plt.xlim(-1.5, 1.5)
    plt.ylim(-2, 2)
    plt.show(True)

# %%
# Com Spearman

N = 100
X = np.linspace(-1, 1, N)
erro = np.random.uniform(-1,1,N) # ruído a ser incluído na relação linear.
for sigma in np.arange(0,3,0.2):
    Y = 0.5*X + erro*sigma
    plt.plot(X,Y, 'ro')
    corrs, p_values = spearmanr(X, Y) # calcula a correlação
    corrs = int(corrs*100)/100
    string = 'corrs = '+ str(corrs)
    plt.text(0.6,1.7, string, fontsize=15)
    plt.xlim(-1.5, 1.5)
    plt.ylim(-2, 2)
    plt.show(True)

# %%
# 6

import matplotlib.pyplot as plt
import numpy as np

# Quarteto de Ascomb

x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
soma = 0

for i in x:
  soma += i

média = soma/len(x)
print('A média de x é', média)

soma = 0

for i in y1:
  soma += i

média = soma/len(y1)
print('A média de y1 é', round(média, 2))

soma = 0

for i in y2:
  soma += i

média = soma/len(y2)
print('A média de y2 é', round(média, 2))

soma = 0

for i in y3:
  soma += i

média = soma/len(y3)
print('A média de y3 é', round(média, 2))

soma = 0

for i in y4:
  soma += i

média = soma/len(y4)
print('A média de y4 é', round(média, 2))
# Out:
# A média de x é 9.0
# A média de y1 é 7.5
# A média de y2 é 7.5
# A média de y3 é 7.5
# A média de y4 é 7.5

# %%
soma = 0

for i in x:
  soma += i

média = soma/len(x)

soma = 0

for j in x:
  var = (j - média)**2
  soma += var

variância = soma/len(x)
print('A variância de x é',  variância)

soma = 0

for i in y1:
  soma += i

média = soma/len(y1)

soma = 0

for i in y2:
  soma += i

média = soma/len(y2)

soma = 0

for j in y2:
  var = (j - média)**2
  soma += var

variância = soma/len(y2)
print('A variância de y2 é',  round(variância, 2))

soma = 0

for i in y3:
  soma += i

média = soma/len(y3)

soma = 0

for j in y3:
  var = (j - média)**2
  soma += var

variância = soma/len(y3)
print('A variância de y3 é',  round(variância, 2))

soma = 0

for i in y4:
  soma += i

média = soma/len(y4)

soma = 0

for j in y4:
  var = (j - média)**2
  soma += var

variância = soma/len(y4)
print('A variância de y4 é',  round(variância, 2))
# Out:
# A variância de x é 10.0
# A variância de y2 é 3.75
# A variância de y3 é 3.75
# A variância de y4 é 3.75

# %%
corr, p_value = pearsonr(x, y1)
corrs, p_values = spearmanr(x, y1)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
print('Correlação de Pearson entre x e y1: ', corr)
print('Correlação de Spearman entre x e y1: ', corrs)
# Out:
# Correlação de Pearson entre x e y1:  0.81
# Correlação de Spearman entre x e y1:  0.81

# %%
corr, p_value = pearsonr(x, y2)
corrs, p_values = spearmanr(x, y2)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
print('Correlação de Pearson entre x e y2: ', corr)
print('Correlação de Spearman entre x e y2: ', corrs)
# Out:
# Correlação de Pearson entre x e y2:  0.81
# Correlação de Spearman entre x e y2:  0.69

# %%
corr, p_value = pearsonr(x, y3)
corrs, p_values = spearmanr(x, y3)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
print('Correlação de Pearson entre x e y3: ', corr)
print('Correlação de Spearman entre x e y3: ', corrs)
# Out:
# Correlação de Pearson entre x e y3:  0.81
# Correlação de Spearman entre x e y3:  0.99

# %%
corr, p_value = pearsonr(x, y1)
corrs, p_values = spearmanr(x, y1)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
string = 'Spearman corr. = '+ str(corrs)
print('Correlação de Pearson entre x e y4: ', corr)
print('Correlação de Spearman entre x e y4: ', corrs)
# Out:
# Correlação de Pearson entre x e y4:  0.81
# Correlação de Spearman entre x e y4:  0.81
